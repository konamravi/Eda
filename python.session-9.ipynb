# %% [markdown]
# **functions**
# - A block of code which we can use many time

# %%
num1=10
num2=20
add=num1+num2
print(add)
# Out:
# 30

# %%
import random
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x000002369FDBB2B0>>

# %%
def <function_name>():
    codelines

# %% [markdown]
# **Functions with out aruguments**

# %%
def addition():
    num1=10
    num2=20
    add=num1+num2
    print(add)

# %%
# function name :addition
# in order to execute code lines
# we need to all

# %%
addition()
# Out:
# 30

# %%
def addition():
    num1=10
    print("num1 is :",num1)
    num2=20
    print("num2 is :",num2)
    add=num1+num2
    print(f"the addition of {num1} and {num2} : {add}")

# %%
addition()
# Out:
# num1 is : 10
# num2 is : 20
# the addition of 10 and 20 : 30

# %% [markdown]
# **Note**
#
# - function name can be anything
# - same rule applicable as variable rules
# - whenever you create the function make sure the indentiation correctly
# - starting with keyword ,ending with colon then code lines start with identiation
# - bracket means functions
# - whenever missed the bracket whenever you vcall the function
# - if you want to excute the  code we need to call the function or bound method
# - wich means you missed the brackets

# %%
def addition():
    num1=10
    print("num1 is :",num1)
    num2=20
    print("num2 is :",num2)
    add=num1+num2
    print(f"the addition of {num1} and {num2} : {add}")    
addition()
# Out:
# num1 is : 10
# num2 is : 20
# the addition of 10 and 20 : 30

# %%
num1=10
num2=20
add=num111+num2
print(add)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 num1=10
#       2 num2=20
# ----> 3 add=num111+num2
#       4 print(add)
#
# NameError: name 'num111' is not defined

# %%
def addition():
    num1=10
    print("num1 is :",num1)
    num2=20
    print("num2 is :",num2)
    add=num1+num2
    print(f"the addition of {num1} and {num2} : {add}")

# %%
addition()
# Out:
# num1 is : 10
# num2 is : 20
# the addition of 10 and 20 : 30

# %% [markdown]
# #### when ever we define the function it does not any throw any error untill unless we call the function

# %%
# wap ask the user 3 number clucleate avreage
num1=eval(input("enter the num1:"))
num2=eval(input("enter the num2:"))
num3=eval(input("enter the num3:"))
avg=(num1+num2+num3)/3
avg1=round(avg)
print(f"the average of {num1},{num2} and {num3} is: {avg}")
# Out:
# enter the num1: 20
# enter the num2: 30
# enter the num3: 40
# the average of 20,30 and 40 is: 30.0

# %%
# function name and variable name should not be same
num1=eval(input("enter the number"))
num2=eval(input("enter the number"))
num3=eval(input("enter the number"))
avg=(num1+num2+num3)/3
avg1=round(avg)
print(f"the average of {num1},{num2} and {num3} is: {avg1}")
# Out:
# enter the number 20
# enter the number 30
# enter the number 40
# the average of 20,30 and 40 is: 30

# %% [markdown]
# - while we are definding function if nothing mentioned means
# - it is called as functionswith out arguments

# %%
def addition()
def average()
def area_of_triangle()
def bill()

# %%
def average():
    num1=eval(input("enter the number"))
    num2=eval(input("enter the number"))
    num3=eval(input("enter the number"))
    avg=(num1+num2+num3)/3
    print(f"the average of {avg}")

# %%
average()
# Out:
# enter the number 10
# enter the number 20
# enter the number 30
# the average of 20.0

# %%
# wap ask the user enter radious value find the area of the circle
radious=eval(input("enter the radious value"))
pi=3.1
area=radious*pi
print(f"the area of the circle: {area}")
# Out:
# enter the radious value 20
# the area of the circle: 62.0

# %%
# wapask the user bill amount, 
# ask the user how much tip you want pay in percentage 
# calucleate total bill
user_bill=eval(input("enter the user bill"))
tip_percentage=eval(input("enter the tip percentage"))

# %% [markdown]
# - why will definding function nothing mention its is called as with out aruguments

# %% [markdown]
# **function with aruguments**
# - first look at how many arugemnt or variables are there
# - in that how many input variable are there
# - how many output variables are there
# - input variables means user can defind
# - out variable means python give output
# - we can use only ninput variables as assigenment inside the function

# %%
def addition2(num1,num2):
    add=num1+num2
    print(f"the addition of {num1} and {num2} is :{add}")

    addition2(10,20)

# %%
addition()
# Out:
# num1 is : 10
# num2 is : 20
# the addition of 10 and 20 : 30

# %%
average(num1,num2,num3) # mistake-1
average()       # mistake-2

# %%
# wap the user enter the base height caluclate area of the triangle 
base=eval(input("enter the base"))
height=eval(input("enter the height "))
area=base*height
print(f" the areaof triangle :{area}")
# Out:
# enter the base 10
# enter the height  20
#  the areaof triangle :200

# %%
def area(base,height):
    area=base*height
    print(f" the areaof triangle :{area}")

# %%
area(10,20)
# Out:
#  the areaof triangle :200

# %%
# try for average

def average1(num1,num2,num3):
        avg=(num1+num2+num3)/3
        avg1=round(avg,2)
        print(f"the aveage  is {num1},{num2} and {num3} is :{avg1}")
        
average1(30,40,50)
# Out:
# the aveage  is 30,40 and 50 is :40.0

# %%
def area(len,bre):
    a=(len*bre)
    print(f"area is {a}")
area(10,20)
# Out:
# area is 200

# %%
def sub():
    n1=eval(input("enter the n1"))
    n2=eval(input("enter the n2"))
    sub=n1-n2
    print(sub)
sub()
# do not pronvide function name and variable name
# Out:
# enter the n1 20
# enter the n2 30
# -10

# %%
def sub(n1,n2):
    sub=n1-n2
    print(sub)
sub(10,20)
# Out:
# -10

# %%
num=eval(input("enter the number:"))
if num%2==0:
    print(f"the {num} is even")
else:
    print(f"the {num}is odd")
# Out:
# enter the number: 15
# the 15is odd

# %% [markdown]
# **Default arguments**

# %%
# bill  amount problem
def bill_pay():
    bill=eval(input("enter the bill:"))
    tip_percentage=eval(input("enter the tip percentage"))
    tip_amount=bill*tip_percentage/100
    total_bill=tip_amount+bill
    print("the total billis:",total_bill)
bill_pay()
# Out:
# enter the bill: 750
# enter the tip percentage 20
# the total billis: 900.0

# %%
# with arguments
#when ever you provide the arguments
# these provided argument are we using inside the code or not
def bill_pay(bill,tip_percentage):
    tip_amount=bill*tip_percentage/100
    total_bill=tip_amount+bill
    print("the total billis:",total_bill)
bill_pay(2000,20)
# Out:
# the total billis: 2400.0

# %%
# bill amount problem
def bill_pay(bill,tip_percentage=20):
    print("bill is:",tip_percentage)
    print("tip_percentage is:",tip_percentage)
    tip_amount=bill*(tip_percentage/100)
    total_bill=tip_amount+bill
    print("the total billis:",total_bill)
  
bill_pay(2000)


# here the tip_percentage =default
# whenever we provided default value to a arguments
# then it is called default argument
# Out:
# bill is: 20
# tip_percentage is: 20
# the total billis: 2400.0

# %%
def average1(num1,num2,num3=50):
        print("num1:",num1)
        print("num2",num2)
        print("num3",num3)
        avg=(num1+num2+num3)/3
        avg1=round(avg,2)
        print(f"the aveage  is {num1},{num2} and {num3} is :{avg1}")
    
average1(30,50)

# num1 num2 are postitional arguments
# num3 is default argument
# Out:
# num1: 30
# num2 50
# num3 50
# the aveage  is 30,50 and 50 is :43.33

# %%
def average1(num1,num2=40,num3):
        print("num1:",num1)
        print("num2",num2)
        print("num3",num3)
        avg=(num1+num2+num3)/3
        avg1=round(avg,2)
        print(f"the aveage  is {num1},{num2} and {num3} is :{avg1}")
    
average1(30,50)
# Out:
#   Cell In[18], line 1
#     def average1(num1,num2=40,num3):
#                               ^
# SyntaxError: non-default argument follows default argument

# %%
def average1(num1,num2,num3=40):
        print("num1:",num1)
        print("num2",num2)
        print("num3",num3)
        avg=(num1+num2+num3)/3
        avg1=round(avg,2)
        print(f"the aveage  is {num1},{num2} and {num3} is :{avg1}")
    
average1(30,50)
# Out:
# num1: 30
# num2 50
# num3 40
# the aveage  is 30,50 and 40 is :40.0

# %% [markdown]
# **Note**
# - default arguments are always at last

# %%
average1(num1,num2,num3=40=40)     # w
average1(num1,num2=50,num3)      # f
average1(num1=100,num2,num3)        #F
average1(num1,num2=50,num3=40)      # w
average1(num1=100,num2,num3=40)      #f
average1(num1=100,num2=50,num3)       #f
average1(num1=100,num2=50,num3=40)   #w

# %%
def average1(num1,num2=50,num3=40):
        print("num1:",num1)
        print("num2",num2)
        print("num3",num3)
        avg=(num1+num2+num3)/3
        avg1=round(avg,2)
        print(f"the aveage  is {num1},{num2} and {num3} is :{avg1}")
    
average1(30)
# Out:
# num1: 30
# num2 50
# num3 40
# the aveage  is 30,50 and 40 is :40.0

# %%
# case-1
def addition(n1,n2=600):
    add=n1+n2
    print(add)
addition(500,600)
# Out:
# 1100

# %%
# case-2
def addition(n1,n2=600):
    add=n1+n2
    print(add)
addition(500,1000)

# first we are defining function
# while definethe function we given n2=600
# now we are calling the function,
# while we are calling n2=1000
# so value will be overwrite 
# python always takes the latest value
# Out:
# 1500

# %%
# case-3
def addition(n1,n2=600):
    n2=2000
    add=n1+n2
    print(add)
    
addition(500,1000)

# a)1100  b)1500   c)2500  d)error

# step-1 :define the function n2=600 
# step-2 : call the function n2=1000
# step-3 : running the function n2=2000
# Out:
# 2500

# %%
# case-4
def addition(n1,n2=600):
    n2=2000
    add=n1+n2
    print(add)
n2=3000    
addition(500,1000)
# n2====> 3000, n2=1000====>1000======> 2500
# Out:
# 2500

# %% [markdown]
# **local variable and global variable**
# - local variable means : the variables inside the function call
# - global variable means : the varoiable outside the function call
# - once you define the variable outside means, you can use those variable anywhere
# - you can global variable inside the function also
# - but you can not use local variable outside the function

# %%
def multiplication():
    a=10
    b=20
    mult=a*b
    print(mult)
multiplication()  

# a,b, mul are local varibles
# these values we can not use out side the function
# Out:
# 200

# %%
mul
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 mul
#
# NameError: name 'mul' is not defined

# %%
a1=100
b1=200
def multiplication():
    mul1=a1*b1
    print(mul1)
multiplication()
# Out:
# 20000

# %%
a1
# Out:
# 100

# %%
b1
# Out:
# 200

# %%
# case-5
a1=100
b1=200
def add11(a1=1000):
    add=a1+b1
    print(add)
add11() 

# a1=1000====>  a1====1000 ====1000+200

#step-1 Global variable intialization  a1=100
#step-2 define the function            a1=1000
#step-3 call the function              a1=1000
# step-4 running th e function         a1=1000
# Out:
# 1200

# %%
# case-6:
a1=100
b1=200
def add11(a1=1000):
    add=a1+b1
    print(add)
add11(a1=2000,b1=3000) 

# while definding function only one argument is there 
# while calling we are providing two arguments
# it is not possible
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 7
#       5     add=a1+b1
#       6     print(add)
# ----> 7 add11(a1=2000,b1=3000)
#
# TypeError: add11() got an unexpected keyword argument 'b1'

# %%
# case-7:
a1=100
b1=200
def add11(a1=1000):
    add=a1+b1
    print(add)
add11(a1=2000)
# Out:
# 2200

# %%
#case-8
a1=100
b1=200
def add11(a1=1000):
    a1=5000
    add=a1+b1
    print(add)
add11(a1=2000)
# Out:
# 5200

# %%
# case-8
a1=100
b1=200
def add11(a1=1000):
    a1=5000
    add=a1+b1
    print(add)
    add=6000
add11(a1=2000)
# Out:
# 5200

# %%
a1
# Out:
# 100

# %%
# case-9:
a1=100
b1=200
def add11(a1=1000):
    a1=5000
    add1=a1+b1
    print(add1)
a1=6000
add11(a1=2000) 
# a1=100,b1=200
#define the function a1=1000
#a1=6000
# calling the a1=5000
# Out:
# 5200

# %%
# case-10:
b1=200
def add11():
    add=a1+b1
    print(add)
a1=6000
add11() 

# b1=200
# define the function 
# a1=6000
# add
# Out:
# 6200

# %%
C
# Out:
# 6200

# %%
# case-11
b1=200
def add11():
    add1=a1+b1
    print(add1)
a1=6000
add11()
# Out:
# 6200

# %%
even throgh we use same variable name a1 in local and global

# %%
a=100
def greet():
    a=200
    print("hello")
greet()
# Out:
# hello

# %%
#step-1 : variable initilised
# step-2 :defindine the function 
# step-3:calling the function 
# step-4 : running the function

# %%
# case-12
b21=200
def add11():
    add1=a21+b21
    print(add21)
a1=6000
add21()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 7
#       5     print(add21)
#       6 a1=6000
# ----> 7 add21()
#
# Cell In[41], line 4, in add21()
#       3 def add21():
# ----> 4     add=a21+b21
#       5     print(add21)
#
# NameError: name 'a21' is not defined

# %%
s=0
def add():
    s=s+10
    print(s)
add()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[3], line 5
#       3     s=s+10
#       4     print(s)
# ----> 5 add()
#
# Cell In[3], line 3, in add()
#       2 def add():
# ----> 3     s=s+10
#       4     print(s)
#
# UnboundLocalError: cannot access local variable 's' where it is not associated with a value

# %%
s=0       #gv
def add():
    a=s+10      #lv
    print(a)
add()
# Out:
# 10

# %%
s=0                 # golable variable
def add():
    c=s+10
    s=c
    print(s)
add()

# step-1:  s=0      gv
# step-2  define the function
# step-3 call the function
# run the function 
#
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[8], line 6
#       4     s=c
#       5     print(s)
# ----> 6 add()
#
# Cell In[8], line 3, in add()
#       2 def add():
# ----> 3     c=s+10
#       4     s=c
#       5     print(s)
#
# UnboundLocalError: cannot access local variable 's' where it is not associated with a value

# %%
n1=10
def addition():
    n1=100
    n2=200
    n3=n1+n2
    print(n1,n2,n3)
addition()
# Out:
# 100 200 300

# %% [markdown]
# **Note**
# - if you give same variable as global and local
# - make sure that  that variable should not use a variable

# %%
n11=10
def addition():
    n22=200+n11
    n33=n11+n22
    print(n11,n22,n33)
addition()




# step-1: n11=10
# step-2: define the function 
# step-3 call the function
# step-4: run the function 
#    n11 is global variable passing inside the function (yes)
#    n22=200+n11=200+10=210
#    n33=10+210=220
#    print(10,210,220)
# Out:
# 10 210 220

# %%
s=0   #gv
def add():
    c=s+10
    s=c   # lv
    print(s)
add()
# step-1: s=0   gv 
# step-2 define the function 
# step-4 call the function 
#      c is lv c=s+10=c=10
#     we are creating a new variable sam elike s 
#we are creating a new variable with same name as global s
# by using global variable

# %%
value=100
def greet():
    value=200
    print('hello')
greet()
# Out:
# hello

# %% [markdown]
# **global**
#
# - global keyword is used to take the local variable value outside value outputs

# %%
value=100
def greet():
    global value
    value=200
    print('hello')
greet()
print("value:",value)
# Out:
# hello
# value: 200

# %%
n1=10
def addition():
    global n33
    
    n2=200
    n3=n1+n2
    print(n1,n2,n3)
addition()
# Out:
# 10 200 210

# %%
n11=10
def addition():
    global n33,n22
    n22=200
    n33=n11+n22
    print(n11,n22,n33)
addition()
# Out:
# 10 200 210

# %%
n22
# Out:
# 200

# %%
n33
# Out:
# 210

# %%
n11=10
def addition():
    global n21,n31
    n21=200
    n31=n11+n22
    print(n11,n22,n33)
addition()
# Out:
# 10 200 210

# %%
n31
# Out:
# 210

# %%
n11
# Out:
# 10

# %%
n21
# Out:
# 200

# %% [markdown]
# - out side the function global variable
# - inside the function local variable
# - local variable can not use outside the function
# - if you want to use outside the function
# - if you wnat to use outside the function use **gloabl** keyword

# %%
def mul(a,b):
    print(a*b)
mul(eval(input()),
    eval(input()))
# Out:
#  20
#  30
# 600

# %% [markdown]
# **Return**

# %% [markdown]
# - we can use local variable or function outputs outside the function using return
# - print is different
# - return is different
# - print is usedto only  to print the value
# - that value you can only see,but you can not use
# - if you want to use outside we will use return (it is also possible by using global)

# %%
def average():
    n1=10
    n2=20
    n3=30
    avg=(n1+n2+n3)/3
    print(avg)
average()
# Out:
# 20.0

# %%
def average():
    n1=10
    n2=20
    n3=30
    avg=(n1+n2+n3)/3
    return(avg)
avg=average()

# function is ready to return values to me
# so i need to store

# %%
avg
# Out:
# 20.0

# %%
def average():
    n1=10
    n2=20
    n3=30
    avg=(n1+n2+n3)/3
    return(avg,n3)
avg,n3=average

# how many values we are returning 
# we will store each return values in different variable
# because two values are differnt
# if you use only variable to store : tuple values

# %%
n3
# Out:
# 30

# %%
avg
# Out:
# 20.0

# %%
print(avg)
print(n3)
# Out:
# 20.0
# 30

# %%
def sub():
    a=10
    b=20
    subb=b-a
    return(subb)

subb=sub()

# %%
subb
# Out:
# 10

# %%
# return alwys  at last line of the function 
# not in middle lines


# sir in real time project , do we use return or global more sir?
# return

# %%
def sub():
    a=10
    b=20
    subb=b-a
    return(a,b,subb)

out=sub()

# %%
out
# Out:
# (10, 20, 10)

# %%
def sub():
    a=10
    b=20
    subb=b-a
    return(a,b,subb)

out=sub()

# %%
out
# Out:
# (10, 20, 10)

# %% [markdown]
# - with out arguments
# - with arguments
# - default argument
# - local vs global
# - global keyboard
# - return
# - function in function
# - *keywargs: keyword arguments

# %% [markdown]
# **unbound local error**

# %%
num1=10
def fun1():
    num=100
    print("inside function:",num)   # print(100)
    
fun1()
print("outside function:",num1)
# Out:
# inside function: 100
# outside function: 10

# %%
num2=10  # gv
def fun2():
    print(num2)
    num2=100   # lv

fun2()


# name error will come 
# local variable and global variable both are name are same 
# you are try to access local variable before assign
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[13], line 6
#       3     print(num2)
#       4     num2=100   # lv
# ----> 6 fun2()
#
# Cell In[13], line 3, in fun2()
#       2 def fun2():
# ----> 3     print(num2)
#       4     num2=100
#
# UnboundLocalError: cannot access local variable 'num2' where it is not associated with a value

# %%
a1=100
b1=200
def add11():
    add11=a1+b1
    print(add11)
add11()
# Out:
# 300

# %%
s=0  #gv 
def add():
    c=s+10
    s=c   # lv
    print(s)
add()

# %%
a1=100
b1=200
def add11():
    add11=a1+b1
    print(add11)
add11()
#here no local veiable as same name as global variable 
a1=100
b1=200

# %%
a1=100
b1=200
def add12():
    a1=500
    b1=700
    add12=b1+a1
    print(add12)
add12()

# we are instalising lv name same as gv 
# we are using lv after intialization
#####################################################################################
a1=100
b1=200def add11():
    add11=a1+b1
    print(add11)
add11()
# we are instalising lv name same as gv 
# we are using lv after intialization
# Out:
# 1200

# %%
def add13():
    a1=500
    b1=700
    add13=b1+a1
    print(add13)
add13()
# Out:
# 1200

# %%
a1=100
b1=200
def add14():
     print(add12)
    a1=500
    b1=700
    add14=b1+a1
add14()
# Out:
#   File <tokenize>:5
#     a1=500
#     ^
# IndentationError: unindent does not match any outer indentation level

# %% [markdown]
# **no error**
# - here no local variable as name as global variable
# - we are intilising loal variable name same as gloable variable
#     - we are using lv after intialization
#
# **error**
# - we are intialising lv name same as gv
# - we are using lv before intialization

# %%
a1=100
b1=200
def add12():
    a1=500
    b1=700
    add12=b1+a1
    print(add12)
add12()


a1=100
b1=200
def add12():
    c=500
    d=700
    add12=c+d
    print(add12)
add12()
# Out:
# 1200
# 1200

# %%
# case-12
b21=200
def add21():
    a21=1000
    add1=a21+b21
    b21=2000
    print(add1)

add21()
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[23], line 9
#       6     b21=2000
#       7     print(add1)
# ----> 9 add21()
#
# Cell In[23], line 5, in add21()
#       3 def add21():
#       4     a21=1000
# ----> 5     add1=a21+b21
#       6     b21=2000
#       7     print(add1)
#
# UnboundLocalError: cannot access local variable 'b21' where it is not associated with a value

# %% [markdown]
# - global variable
# - difine the function
# - call the function
# - run the function

# %% [markdown]
# **Function in Function**

# %%
def greet1():
    print("hello good morning")
def greet2():
    print("good night")
greet1()
greet2()
# hello good morning
# good night
# Out:
# hello good morning
# good night

# %%
def greet2():
    print("good night")
def greet1():
    print("hello good morning")
greet1()
greet2()
# Out:
# hello good morning
# good night

# %%
def greet1():
    print("hello good morning")
    greet2()
def greet2():
    print("good night")
    greet1()
greet2()

# hello good morning 
# greet2======gn
# greet1======hello good morning
# Out:
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# hello good morning
# good night
# ...

# %% [markdown]
# - Function withb out arguments
# - Function with arguments
# - function default arguments
# - global variable vs local variable
# - global keyword
# - return statement
# - unbound local error
# - function in function

# %%
distance=eval(input("enter the distance in km"))
cutoff_distance=eval(input("enter the cutoff distance in km:"))
if distance>cutoff_distance:
    charageble_distance=distance-cutoff_distance
    print("kudos to you the chargeble distance is:",charageble_distance)
    chargeble=eval(input("enter the chargeble distance in rs:"))
    cost=charageble_distance*charge
    print("the total charge is:", cost)
else:
    print("your free ride")
# Out:
# enter the distance in km 80
# enter the cutoff distance in km: 20
# kudos to you the chargeble distance is: 60
# enter the chargeble distance in rs: 40
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 7
#       5     print("kudos to you the chargeble distance is:",charageble_distance)
#       6     chargeble=eval(input("enter the chargeble distance in rs:"))
# ----> 7     cost=charageble_distance*charge
#       8     print("the total charge is:", cost)
#       9 else:
#
# NameError: name 'charge' is not defined

# %%
distance=eval(input("enter the distance in km"))
cutoff_distance=eval(input("enter the cutoff distance in km:"))
def total_feare():
    if distance>cutoff_distance:
        charageble_distance=distance-cutoff_distance
        print("kudos to you the chargeble distance is:",charageble_distance)
        charge=eval(input("enter the chargeble distance in rs:"))
        cost=charageble_distance*charge
        print("the total charge is:", cost)
    else:
        print("your free ride")
        
total_feare()

print("outside function cost is:",cost)
# Out:
# enter the distance in km 100
# enter the cutoff distance in km: 20
# kudos to you the chargeble distance is: 80
# enter the chargeble distance in rs: 30
# the total charge is: 2400
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[52], line 15
#      11         print("your free ride")
#      13 total_feare()
# ---> 15 print("outside function cost is:",cost)
#
# NameError: name 'cost' is not defined

# %%
distance=eval(input("enter the distance in km"))
cutoff_distance=eval(input("enter the cutoff distance in km:"))
def total_feare():
    if distance>cutoff_distance:
        charageble_distance=distance-cutoff_distance
        print("kudos to you the chargeble distance is:",charageble_distance)
        charge=eval(input("enter the chargeble distance in rs:"))
        cost=charageble_distance*charge
        print("the total charge is:",cost)
    else:
        cost=100
        return(cost)
        
total_feare()

print("outside function cost is:",cost)
# Out:
# enter the distance in km 6666
# enter the cutoff distance in km: 77
# kudos to you the chargeble distance is: 6589
# enter the chargeble distance in rs: 545
# the total charge is: 3591005
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 16
#      12         return(cost)
#      14 total_feare()
# ---> 16 print("outside function cost is:",cost)
#
# NameError: name 'cost' is not defined

# %%
# first create 4 individual function 
# fun1: add
# fun2: sub
# fun3: mul
# fun4: div

def add(a,b):
    print(a+b)

# create  a main function name : caluculater
# inside main function 
# print same statements
# option1: addition
# option2: sub,
# option3: mul
# opetion4: div
#opetion=eval(input('1-4'))
# a value
# b value
# if option==1:
#     add function
#elif opetion==2:
#     sub function
#elif opetion==3:
#     mul function
#elif opetion==4:
#     div function

# %%
def add(a,b):
    print(a+b)

def sub(a,b):
    print(a-b)

def mul(a,b):
    print(a*b)
    
def div(a,b):
    print(a/b)

def calculater():
    print("option1 is addition")
    print("option2 is multiplication")
    print("option3 is substraction")
    print("option4 is division")
    op=eval(input("enter a operation 1 to 4 :"))
    a=eval(input("enter the a"))
    b=eval(input("enter the b"))

    if op==1:
        add(a,b)
    elif op==2:
        sub(a,b)
    elif op==3:
        mul(a,b)
    elif op==4:
        div(a,b)
    else :
        print("enter a valid number")
calculater()
# Out:
# option1 is addition
# option2 is multiplication
# option3 is substraction
# option4 is division
# enter a operation 1 to 4 : 3
# enter the a 10
# enter the b 20
# 200
