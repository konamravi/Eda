# %% [markdown]
# **File handling**

# %%
File name                         Type of file          

text                                 .text

word                                 .doc or docx

pdf                                   .pdf

CSV(Excel)                            csv(coma seperate value)(tabular)

Excel                                .xlsx(Tabular)

=========================================unstructured================================
XML                              .xml (Image data)

Parquet                          .delta/.parquet (DE)

Delta                            .delta (DE)

Image                            .jpg,.JPEG,.png

Video                            .mp4

Audio                            .mp3
# Out:
#   Cell In[1], line 1
#     File name
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# **Task**

# %% [markdown]
# - Get the package name to read each file

# %% [markdown]
# **How to read the text file**
#
# - In order to read any file,we need 3 points
#
# - where is the file located: dictionary or folder name
#
#     'C:\Users\Lenovo\Downloads'
#
# - what is the file name
#
#     - 'mbox-short'
#
# - What is the extenssion of the file
#
#    - '.text'
# - location\filename.typeoffile

# %%
path="C:\\Users\\Lenovo\\Downloads\\mbox-short.txt"
print(path)
# Out:
# C:\Users\Lenovo\Downloads\mbox-short.txt

# %% [markdown]
# **Task**

# %%
path_andriod_games

# %%
f1=open("file_1.text")

# %%
data=f1.read()

# %%
print(data)

# %%
path1_mbox_short="C:\Users\Lenovo\Downloads\mbox-short.txt"
# Out:
#   Cell In[9], line 1
#     path1_mbox_short="C:\Users\Lenovo\Downloads\mbox-short.txt"
#                                                                ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
path_mbox_short=r"C:\Users\Lenovo\Documents\naresh it\python\mbox-short.txt"
path_mbox_short
# Out:
# 'C:\\Users\\Lenovo\\Documents\\naresh it\\python\\mbox-short.txt'

# %%
# you are able to write the path 
# Folder name
# file name 
# Extension

# %% [markdown]
# **Unicode error**
#
# - whenever we see apply the single slash python gives the error
#
# - this is caled as unicode error
#
# - uni means one
#
# - unicode means you need to provide double slash
#
# - we can avoid unicode error by providing a **r** letter starting of the path

# %%
"C:\\Users\\Lenovo\\Downloads\\mbox-short.txt"
# Out:
# 'C:\\Users\\Lenovo\\Downloads\\mbox-short.txt'

# %%
r"C:\Users\Lenovo\Downloads\mbox-short.txt"
# Out:
# 'C:\\Users\\Lenovo\\Downloads\\mbox-short.txt'

# %%
# Folder name 
# Diffrent users having differn dirctory
# observe Root folder or Root directionary

# %% [markdown]
# **Read the file**
#
# - step-1: Take the path
#
# - step-2: open the file
#
# - step-3: read the file

# %%
path1_mbox_short="C:\Users\Lenovo\Downloads\mbox-short.txt"
open(path)

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\Documents\\naresh it\\python'

# %%
path=r"C:\Users\Lenovo\Downloads\mbox-short.txt"
file=open(path)
data=file.read()
print(data)

# This method applicable only for text file
# We can not read any other files like csv,excel,word,pdf
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %%
'r'      open for reading (default)

'w'      open for writing, truncating the file first
         We load the data which has already have information
         That information will gone, that is called as Truncating

'x'      create a new file and open it for writing
         Imagine that there is no empty file in your local
         It will create the file and write the information

'a'      open for writing, appending to the end of the file if it exists
         Already information is there, we want add some more

'b'      binary mode
         binary is a data type : b'abc'

't'     text mode (default)
'+'     open a disk file for updating (reading and writing)

# %% [markdown]
# **File NOt Found Error**
#
# - checking
#
# - which we are passing

# %% [markdown]
# **Method-2**
#
# - When in real time diffenent laptop different root folders
#
# - it is not a good way provide full path which root directory
#
# - so that we will keep data file in python location it self
#
# - Which means both datafile and python file in same location
#
# - Then no need to provide folder name
#
# - only file name and extension is enough

# %%
path=r"mbox-short.txt"
file=open(path)
data=file.read()
print(data)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\Documents\\naresh it\\python'

# %%
path=r"C:\Users\Lenovo\Downloads\mbox-short.txt"
file=open(path)
data=file.read()
print(data)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %%
data
# Out:
# 'From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008\nReturn-Path: <postmaster@collab.sakaiproject.org>\nReceived: from murder (mail.umich.edu [141.211.14.90])\n\t by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;\n\t Sat, 05 Jan 2008 09:14:16 -0500\nX-Sieve: CMU Sieve 2.3\nReceived: from murder ([unix socket])\n\t by mail.umich.edu (Cyrus v2.2.12) with LMTPA;\n\t Sat, 05 Jan 2008 09:14:16 -0500\nReceived: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])\n\tby flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;\n\tSat, 5 Jan 2008 09:14:15 -0500\nReceived: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])\n\tBY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ; \n\t 5 Jan 2008 09:14:10 -0500\nReceived: from paploo.uhi.ac.uk (localhost [127.0.0.1])\n\tby paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;\n\tSat,  5 Jan 2008 14:10:05 +0000 (GMT)\nMessage-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>\nMime-Version: 1.0\n
# ...

# %% [markdown]
# **Method-3**

# %% [markdown]
# **using with keyword**

# %% [markdown]
# - When we use open and read in different lines
#
# - python indirctly takes the seesion apporach
#
# - The session will close after some time
#
# - The stored data will not able to use (its gone)
#
# - The we need to perform the same operations under session
#
# - by using **with** key word

# %%
path=r"C:\Users\Lenovo\Downloads\mbox-short.txt"
file=open(path)
data=file.read()
print(data)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %%
path=r"mbox-short.txt"
file=open(path)
data=file.read()
print(data)

# %%
path=r"mbox-short.txt"
with open(path) as file:
    data=file.read()

# %%
print(data)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %% [markdown]
# **Encoding**

# %% [markdown]
# - Encoding is a method to hide the character for the security purpose
#
# - When ever we read some file we have some sql character
#
# - To avoid those we will use encoding argument while open the file path
#
# - We have so many encoding method are there
#
# - **utf-8-sig** is one of the main encoding method
#
# **Mode**
#
# - while opening the file there is mode argument
#
# - By defalut mode ='r' with mean read
#
# - If you want to write mode= 'w'
#
#
# **File not found error**
#
# - File not found error mean ,file is not available in the given path
#
# - This is competely our job : This error made by us only
#
# - go to path, the chek the file name that location
#
#
# **permision**
#
# - The file we are using in python is already opened in ur jupyter
#
# - you might be see or might not able to see
#
# - If you dont see the opened file,
#
# - If you see the opend file,restart the computer
#
# - agaiunopen only jupyter notebook and excute the cell

# %%
path_mbox_short=r"mobx-short.txt"
with open(path_mbox_short,mode='r',encoding='utf-8-sig') as file:
    data=file.read()
print(data)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 path_mbox_short=r"mobx-short.txt"
# ----> 2 with open(path_mbox_short,mode='r',encoding='utf-8-sig') as file:
#       3     data=file.read()
#       4 print(data)
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mobx-short.txt'

# %%
# you are providing a only file name 
# what is that meaning 
# same directory :
# pyhon folder 

# so we need check in that python folder 
# file name

# %% [markdown]
# **Write the file**

# %%
# take method-2
path_mbox_short1=r"mbox-short.txt"
file=open(path_mbox_short1,mode='w')
data=file.write("Hello plese follow")
print(data)
# Out:
# 18

# %% [markdown]
# - Write the file also same way like read the file
#
# - **Check point number-1**
#
#   - What is the file name ,which you want to write some thing
#
#   - is that file existed in yoyr laptop or not
#
#   - generally we will give the new name, that is not existed in your laptop
#
# - **Check point number-2**
#
#   - chose the correct  mode
#
#   - for writting we have many modes
#
#      - mode='w': clear the existed data
#
#      - mode='a'
# - **check point number-3**
#
#   - For reading we will use read
#
#   - for writting we will use write

# %%
path="writefile1.txt"
file=open(path,mode='w')
data=file.write("Hello")
data
# Out:
# 5

# %%
path="writefile1.txt"
with open(path,mode='w')as file
data=file.write("Hello")
data

# %% [markdown]
# **itearting each line using for loop**

# %%
# read the mbo-short using method-2
# apply the for loop and print it

path='mbox-short.txt'
file=open(path)
data=file.read()
for i in data.split('\n'):
    print(i)
# Out:
# Hello plese follow

# %%
# apply the mbox-short 
# apply the for loop and print it 
path='mbox-short.txt'
file=open(path,mode='r',encoding='utf-8-sig')
data=file.read()
for i in data.split('\n'):
    print(i)
# Out:
# Hello plese follow

# %%
path="writefile.txt"
file=open(path,mode='w')
data=file.write('hello plesefollow checkpoints')
data
# Out:
# 29

# %%
len('hello plesefollow checkpoints')
# Out:
# 29

# %%
# you are providing a only file name
# what is that meaning 
# smae directory
# same folder
# python folder

# so we need check in that python folder
# the file is avilable or not

# %%
# Name Error: name 'r' is not defined

# r====black color===variable

# %%
path="writefile1.txt"
file=open(path,mode='w')
data=file.write('Hello please follow checkpoints')
data
# Out:
# 31

# %%
# read the mbox-short using metho2
# apply the for loop and print it
path='mbox-short.txt'
file=open(path,mode='r',encoding='utf-8-sig')
data=file.read()
for i in data.split('\n'):
    print(i)
# Out:
# Hello plese follow

# %%
path='mbox-short.txt'
file=open(path,mode='r',encoding='utf-8-sig')
for i in file:
    print(i)
# Out:
# Hello plese follow

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\Documents\\naresh it\\python'

# %%
# your mbox-short in 
# c drive ===Desktop===python intermediate

# %%
# Read the file

# %%
# You want to save output in adifferent folder
# But in same root dirctionary

# Get your python location folder
import os
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\Documents\\naresh it\\python'

# %%
path=r"C:\Users\Lenovo\Documents\naresh it\python\output\writ_file_txt"
with open(path,mode='w')as file:
    file.write('Hello please follow checkpoints')

# %% [markdown]
# - Here we created manually the folder name:  **OUTPUT**
#
# - This folder in same python root dirctory
#
# - python root dirctory is :
#
#    - C:\Users\Lenovo\Documents\naresh it\python
#
# - OUTPUT root dictionary:
#
#   - \Users\Lenovo\Documents\naresh it\python\output
#
# - Whenever in the situation we no need to creat a folder manually
#
# - we will creat a folder by using **os** package

# %%
os.getcwd()+'outputs'
# Out:
# 'C:\\Users\\Lenovo\\Documents\\naresh it\\pythonoutputs'

# %%
file_name='output'
os.getcwd()+'\\'+folder_name # Workng
os.getcwd()+'/'+folder_name # not working
os.getcwd()+f"{folder_name}"  # working
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 2
#       1 file_name='output'
# ----> 2 os.getcwd()+'\\'+folder_name # Workng
#       3 os.getcwd()+'/'+folder_name # not working
#       4 os.getcwd()+f"{folder_name}"
#
# NameError: name 'os' is not defined

# %% [markdown]
# **How to creat a folder**

# %% [markdown]
# **os.makedirs**
# - This is a method to create folder

# %%
current_path=os.getcwd()
folder_name='output'
new_dir=os.path.join(current_path,folder_name)
os.makedirs(new_dir)

# %%
try:
    current_path=os.getcwd()
    folder_name='output'
    new_dir=os.path.join(current_path,folder_name)
    os.makedirs(new_dir)
except Exception as e:
    print(e)
# Out:
# [WinError 183] Cannot create a file when that file already exists: 'C:\\Users\\Lenovo\\Documents\\naresh it\\python\\output'

# %%
file_name='write_file.txt'
path=os.path.join(new_dir,file_name)
with open(path,mode='w') as file:
    file.write('Hello please follow checkpoint')

# %%
with open(path,mode='r')  as file:
    data=file.read()
print(data)
# Out:
# Hello please follow checkpoint

# %% [markdown]
# - step-1: creat a folder
#
# - step-2: To create a folder we will use: os.makedir()
#
# - step-3: os.dirs will take the path
#
#   - path is full folder path
#
#   - imagine that if you creat a folder What is the full path
#
#   - c:\users\...............\folder_name
#
# - step-4: again in this we have two things
#
#   - currnent working directory
#
#   - folder name
#
#   - we are telling to python you concatenatenate both
#
#
# - step-5: os.path.join will concatenate both current working dir and folder_name

# %%
cwd=os.getcwd()
cwd
folder_name='output'
new_dirs=os.path.join(cwd,folder_name)
new_dir
os.makedirs(new_dir)
# Out:
# 'C:\\Users\\Lenovo\\Documents\\naresh it\\python\\output'

# %%
'C:\\Users\\Lenovo\\Documents\\naresh it\\python\\output'
file_name='file.txt'
os.path.join(new_dir

# %%
folder_dir=new_dir
file_name='file.txt'
path=os.path.join(folder_dir,file_name)
with open(path,mode='w') as file:
    file.write('Hello please follow checkpoint')

# %%
with open(path,mode='r') as file:
    data=file.read()
print(data)
# Out:
# Hello please follow checkpoint

# %%
path='writefile01.txt'
file=open(path,mode='w')
data=file.write('Hello please follow checkpoints')
data
# Out:
# 31

# %%
len('Hello please follow checkpoints')
# Out:
# 31

# %%
path='writefile02.txt'
with open(path,mode='w') as file:
    file.write('Hello please follow check point')
    file.write('if not follow')

# %%
path='mbox-short.txt'
file=open(path,mode='r',encoding='utf-8-sig')
data=file.read()
for i in data.split('\n'):
    print(i)

# %%
path='mbox-short.txt'
file=open(path,mode='r',encoding='utf-8-sig')
for i in file:
    print(i)

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Lenovo\\Documents\\naresh it\\python'

# %%
path='C:\\Users\\Lenovo\\Documents\\naresh it\\python\\output'
with open(path,mode='w')as file :
    file.write('Hello please folow check points')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[14], line 2
#       1 path='C:\\Users\\Lenovo\\Documents\\naresh it\\python\\output'
# ----> 2 with open(path,mode='w')as file :
#       3     file.write('Hello please folow check points')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:310, in _modified_open(file, *args, **kwargs)
#     303 if file in {0, 1, 2}:
#     304     raise ValueError(
#     305         f"IPython won't let you open fd={file} by default "
#     306         "as it is likely to crash IPython. If you know what you are doing, "
#     307         "you can use builtins' open."
#     308     )
# --> 310 return io_open(file, *args, **kwargs)
#
# PermissionError: [Errno 13] Permission denied: 'C:\\Users\\Lenovo\\Documents\\naresh it\\python\\output'

# %%
try :
    new_path=os.getcwd()
    folder_name='output'
    new_dir=os.path.join(new_path,folder_name)
    os.makedires(new_dir)
except except
# Out:
#   Cell In[15], line 5
#     os.makedires(new_dir)
#                          ^
# SyntaxError: incomplete input

# %% [markdown]
# **find the Number of line in mbox-short file**

# %%
# Read the mbox-short 
path=r"C:\Users\Lenovo\Downloads\mbox-short.txt"
file=open(path)
data=file.read()
print(data)
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# 	 Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# 	Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 	 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# ...

# %%
path=r"C:\Users\Lenovo\Downloads\mbox-short.txt"
file=open(path)
count=0
for i in file:
    count=count+1
    
print(count)
# Out:
# 1910

# %% [markdown]
# **Enumerate**
#
# - enumerate is a in built function like zip
#
# - it will give two values
#
#   - one is index of the line
#
#   - second is actual line

# %%
path=r"C:\Users\Lenovo\Downloads\mbox-short.txt"
file=open(path)
for ix,line in enumerate(file):
   print(ix,line)
# Out:
# 0 From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
#
# 1 Return-Path: <postmaster@collab.sakaiproject.org>
#
# 2 Received: from murder (mail.umich.edu [141.211.14.90])
#
# 3 	 by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
#
# 4 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 5 X-Sieve: CMU Sieve 2.3
#
# 6 Received: from murder ([unix socket])
#
# 7 	 by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
#
# 8 	 Sat, 05 Jan 2008 09:14:16 -0500
#
# 9 Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
#
# 10 	by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
#
# 11 	Sat, 5 Jan 2008 09:14:15 -0500
#
# 12 Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
#
# 13 	BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
#
# 14 	 5 Jan 2008 09:14:10 -0500
#
# 15 Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
#
# 16 	by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
#
# 17 	Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
#
# ...

# %%
path=r"C:\Users\Lenovo\Downloads\mbox-short.txt"
file=open(path)
count=0
for ix,line in enumerate(file):
    count=count+1
print(ix,line)
# Out:
# 1909

# %%
ix
# Out:
# 1909

# %% [markdown]
# - Whenever we defined one variable
#
# - that variable is not using
#
# - with out that variable the code will not work
#
# - that variable we can replace with pass

# %%
path=r"C:\Users\Lenovo\Downloads\mbox-short.txt"
file=open(path)
for index,_ in enumerate(file):
   pass

index+1
# Out:
# 1910

# %% [markdown]
# **Q2)when you read the data some of the lineare not in alignment**

# %%
path=r"C:\Users\Lenovo\Downloads\mbox-short.txt"
file=open(path)
for line in file:
    print(line.strip())
# Out:
# From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008
# Return-Path: <postmaster@collab.sakaiproject.org>
# Received: from murder (mail.umich.edu [141.211.14.90])
# by frankenstein.mail.umich.edu (Cyrus v2.3.8) with LMTPA;
# Sat, 05 Jan 2008 09:14:16 -0500
# X-Sieve: CMU Sieve 2.3
# Received: from murder ([unix socket])
# by mail.umich.edu (Cyrus v2.2.12) with LMTPA;
# Sat, 05 Jan 2008 09:14:16 -0500
# Received: from holes.mr.itd.umich.edu (holes.mr.itd.umich.edu [141.211.14.79])
# by flawless.mail.umich.edu () with ESMTP id m05EEFR1013674;
# Sat, 5 Jan 2008 09:14:15 -0500
# Received: FROM paploo.uhi.ac.uk (app1.prod.collab.uhi.ac.uk [194.35.219.184])
# BY holes.mr.itd.umich.edu ID 477F90B0.2DB2F.12494 ;
# 5 Jan 2008 09:14:10 -0500
# Received: from paploo.uhi.ac.uk (localhost [127.0.0.1])
# by paploo.uhi.ac.uk (Postfix) with ESMTP id 5F919BC2F2;
# Sat,  5 Jan 2008 14:10:05 +0000 (GMT)
# Message-ID: <200801051412.m05ECIaH010327@nakamura.uits.iupui.edu>
# Mime-Version: 1.0
# ...

# %% [markdown]
# **Q3)get lines which are starting with From**

# %%
path=r"C:\Users\Lenovo\Downloads\mbox-short.txt"
file=open(path)
from_list=[]
for line in file:
    if line.startswith('From'):
        from_list.append(line)

# %%
path=r"C:\Users\Lenovo\Downloads\mbox-short.txt"
file=open(path)
from_list=[line for line in file if line.startswith('From')]
len(from_list)
# Out:
# 54

# %%
from_list
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from_list
#
# NameError: name 'from_list' is not defined

# %% [markdown]
# **Q4) In above output we need to remove \n at the end**

# %% [markdown]
# - take above output as input
#
# - iterate is apply rstrip
#
# - keep in another list

# %%
list=[]
for line in from_list:
    list.append(line.rstrip('\n'))

# %%
list
# Out:
# ['From stephen.marquard@uct.ac.za Sat Jan  5 09:14:16 2008',
#  'From: stephen.marquard@uct.ac.za',
#  'From louis@media.berkeley.edu Fri Jan  4 18:10:48 2008',
#  'From: louis@media.berkeley.edu',
#  'From zqian@umich.edu Fri Jan  4 16:10:39 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 15:46:24 2008',
#  'From: rjlowe@iupui.edu',
#  'From zqian@umich.edu Fri Jan  4 15:03:18 2008',
#  'From: zqian@umich.edu',
#  'From rjlowe@iupui.edu Fri Jan  4 14:50:18 2008',
#  'From: rjlowe@iupui.edu',
#  'From cwen@iupui.edu Fri Jan  4 11:37:30 2008',
#  'From: cwen@iupui.edu',
#  'From cwen@iupui.edu Fri Jan  4 11:35:08 2008',
#  'From: cwen@iupui.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:12:37 2008',
#  'From: gsilver@umich.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:11:52 2008',
#  'From: gsilver@umich.edu',
#  'From zqian@umich.edu Fri Jan  4 11:11:03 2008',
#  'From: zqian@umich.edu',
#  'From gsilver@umich.edu Fri Jan  4 11:10:22 2008',
# ...

# %%
path='mbox-short.txt'
file=open(path)
from_list=[line.rstrip('\n') for line in file if line.startswith('From')]
len(from_list)
# Out:
# 0

# %%
#Q5) from above output 
# you need to extract all the email

#Q6) unique emails

#q7) you need to read the text file

Nallagoni,omkar<omkar.nallagoni@accenture.com
fname=Nallagonu
sname=omkar
emailid
cname=accenture
